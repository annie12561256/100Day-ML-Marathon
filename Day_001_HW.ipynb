# %% [markdown]
# 作業1：Mean Square Error

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y, yp):
  
    n = len(y)
    mse = sum(np.square(y - yp))/n
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 177.550
# The Mean absolute error is 10.659

# %% [markdown]
# 作業2

# %% [markdown]
# 1.你選的這組資料為何重要?
#   因為大學專題是手動調整EMG的參數，
#   如果透過數據分析後，讓程式抓取使用者的EMG即可產生參數

# %% [markdown]
# 2資料從何而來
#  提供者是:Kirill Yashuk
#  https://www.kaggle.com/kyr7plus/myo-emg-leap-motion-capture

# %% [markdown]
# 3.蒐集而來的資料型態為何?
#   表格

# %% [markdown]
# 4.這組資料想解決的問題如何評估:
#   -1.使假肢裝置具有多個自由度
#   -2.該數據集可用於將殘餘肌肉手勢映射到假肢的某些動作，例如打開/關閉手或旋轉手腕。

# %% [markdown]
# 作業3
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

# %% [markdown]
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#    ANS-如何增加客人使用公司的app，以及希望公司有何改善的地方

# %% [markdown]
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#    ANS-顧客問卷調查的紙本轉電⼦子檔

# %% [markdown]
# 3. 蒐集而來的資料型態為何
#    ANS-表格

# %% [markdown]
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#    ANS-概率原理
